# %%
# import lib
from __future__ import print_function
import numpy as np 
import math
import h5py
import matplotlib.pyplot as plt
import scipy
from PIL import Image
from scipy import ndimage
import tensorflow as tf
from tensorflow.python.framework import ops
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
# data processing
# %run 'data preprocessing.py'
# Gaussian
#%run 'DA-Gaussian.ipynb'
# salt&pepper
#%run 'DA-salt&pepper.ipynb'
# perspective
#%run 'DA-perspective.ipynb'
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of validation examples = " + str(X_val.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_val shape: " + str(X_val.shape))
print ("Y_val shape: " + str(Y_val.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# Loading training set...
# Done
# Loading test set...
# Done
# Splitting into val/test set...
# Done
# Normalization...
# Done
# Converting to one-hot code...
# Done
# Finished!
# number of training examples = 28736
# number of validation examples = 4841
# number of test examples = 4832
# X_train shape: (28736, 100, 100, 3)
# Y_train shape: (28736, 60)
# X_val shape: (4841, 100, 100, 3)
# Y_val shape: (4841, 60)
# X_test shape: (4832, 100, 100, 3)
# Y_test shape: (4832, 60)

# %%
# create placeholder for x and y
def create_placeholders(n_H0, n_W0, n_C0, n_y):

    X = tf.placeholder(tf.float32, shape=[None, n_H0, n_W0, n_C0])
    Y = tf.placeholder(tf.float32, shape=[None, n_y])
    
    return X, Y

x, y = create_placeholders(100, 100, 3, 60)
print ("x = " + str(x))
print ("y = " + str(y))
# Out:
# x = Tensor("Placeholder:0", shape=(?, 100, 100, 3), dtype=float32)
# y = Tensor("Placeholder_1:0", shape=(?, 60), dtype=float32)

# %%
# initialize parameters

def initialize_parameters():
    
    tf.set_random_seed(1)
    
    w1_shape = [3,3,3,16]
    w2_shape = [3,3,16,32]
    w3_shape = [3,3,32,32]
    w4_shape = [3,3,32,64]

    
    w1 = tf.get_variable('w1', w1_shape, initializer = tf.contrib.layers.xavier_initializer(seed=0))
    w2 = tf.get_variable('w2', w2_shape, initializer = tf.contrib.layers.xavier_initializer(seed=0))
    w3 = tf.get_variable('w3', w3_shape, initializer = tf.contrib.layers.xavier_initializer(seed=0))
    w4 = tf.get_variable('w4', w4_shape, initializer = tf.contrib.layers.xavier_initializer(seed=0))
    
    parameters = {'w1': w1, 'w2': w2, 'w3': w3, 'w4': w4}
    
    return parameters

# %%
# forward_propagation

def forward_propagation(x, parameters, prob):
    # retrieve weights
    w1 = parameters['w1']
    w2 = parameters['w2']
    w3 = parameters['w3']
    w4 = parameters['w4']
    
    # conv1: k = (3,3), input = (100,100,3), output = 16, padding=0, stride =1
    x = tf.nn.conv2d(x, w1, strides = [1, 1, 1, 1], padding = 'SAME')
    # batchnormalization
    x = tf.layers.batch_normalization(x)
    # relu
    x = tf.nn.leaky_relu(x, alpha=0.5)
    # maxpool: (2,2), stride = 2, padding = 0
    x = tf.nn.max_pool(x, ksize=[1,2,2,1], strides = [1,2,2,1], padding = 'VALID')

    
    # conv2: k = (3,3), input = 16, output = 32
    x = tf.nn.conv2d(x, w2, strides = [1,1,1,1], padding = 'SAME')
    # batchnormalization
    x = tf.layers.batch_normalization(x)
    # relu
    x = tf.nn.leaky_relu(x, alpha=0.5)
    # maxpool: (2,2)
    x = tf.nn.max_pool(x, ksize=[1,2,2,1], strides = [1,2,2,1], padding = 'VALID')
    
    # conv3
    x = tf.nn.conv2d(x, w3, strides = [1,1,1,1], padding = 'SAME')
    # batchnormalization
    x = tf.layers.batch_normalization(x)
    # relu
    x = tf.nn.leaky_relu(x, alpha=0.5)
    # maxpool: (2,2)
    x = tf.nn.max_pool(x, ksize=[1,2,2,1], strides = [1,2,2,1], padding = 'VALID')
    
    # conv4
    x = tf.nn.conv2d(x, w4, strides = [1,1,1,1], padding = 'SAME')
    # batchnormalization
    x = tf.layers.batch_normalization(x)
    # relu
    x = tf.nn.leaky_relu(x, alpha=0.5)
    # maxpool: (2,2)
    x = tf.nn.max_pool(x, ksize=[1,2,2,1], strides = [1,2,2,1], padding = 'VALID')
              
    # flatten
    x = tf.contrib.layers.flatten(x)
    
    # fully-connected 
    # dense1
    x = tf.contrib.layers.fully_connected(x, 256, activation_fn = tf.nn.relu)
    # dropout
    x = tf.nn.dropout(x, keep_prob=prob)
    
    # dense2
    y = tf.contrib.layers.fully_connected(x, 60, activation_fn = None)
    
    return y

# %%
# compute cost
def compute_cost(y_pred, y):
    var   = tf.trainable_variables()
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = y_pred, labels = y))
    return cost

def compute_accuracy(y_pred, x, y, size, x_, y_, prob, dropout):
    correct_prediction = tf.equal(tf.argmax(tf.nn.softmax(y_pred),1), tf.argmax(y,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    num = int(x_.shape[0]/size)
    acc_ = 0
    for i in range(num):
        acc = accuracy.eval({x:x_[i*size:(i+1)*size], y:y_[i*size:(i+1)*size], prob:dropout})
        acc_ += acc/num

    return acc_

# %%
# training
def training(xtrain, ytrain, xtest, ytest, alpha = 0.001, epochs = 30, minibatch_size = 256, print_cost = True):  
   
    ops.reset_default_graph()
    tf.set_random_seed(1)
    (m, n_H0, n_W0, n_C0) = xtrain.shape
    n_y = ytrain.shape[1]
    costs = []
    costs_test = []
    accs_train = []
    accs_test = []
    minibatch_num = int(m/minibatch_size)
    
    x,y = create_placeholders(n_H0, n_W0, n_C0, n_y)
    prob = tf.placeholder_with_default(1.0, shape=())
    
    # initialize
    parameters = initialize_parameters()
    
    # forwardprop
    y_pred = forward_propagation(x, parameters, prob)
    
    # cost function
    cost = compute_cost(y_pred, y)
    
    # backprop
    optimizer = tf.train.AdamOptimizer(alpha).minimize(cost)
       
    # initialize
    init = tf.global_variables_initializer()
    init2 = tf.local_variables_initializer()
    
     
    
    # session
    with tf.Session() as sess:
        sess.run(init)
        sess.run(init2)
                    
        # training
        for epo in range(epochs):
            tf.set_random_seed(1)
            minibatch_cost = 0
            cost_test = 0
            
            # shuffle
            minibatch = np.random.choice(np.random.permutation(m), 
                                         minibatch_size * minibatch_num).reshape(minibatch_num, minibatch_size)
            minibatch_index = np.random.permutation(minibatch_num)  
                       
            for mb in range(minibatch_num):
                i = minibatch_index[mb]
                indx = minibatch[i]
                inputs = xtrain[indx]
                labels = ytrain[indx]

                # feed the inputs
                _, temp_cost = sess.run([optimizer, cost], feed_dict={x: inputs, y: labels, prob:0.5})
                
                # calculate average cost after 1 epoch
                minibatch_cost += temp_cost / minibatch_num
            
            
            # calculate cost of test set after 1 epoch
            for i in range(5):
                temp_test = sess.run(cost, feed_dict={x:xtest[i*967:(i+1)*967], y:ytest[i*967:(i+1)*967], prob:1})
                cost_test += temp_test / 5

            
            # add cost of this epoch to the lists
            costs.append(minibatch_cost)
            costs_test.append(cost_test)
            
            acc_train = compute_accuracy(y_pred, x, y, 967, xtrain, ytrain, prob, dropout=0.5) 
            accs_train.append(acc_train)
            acc_test = compute_accuracy(y_pred, x, y, 967, xtest, ytest, prob, dropout=1) 
            accs_test.append(acc_test)
 
            
            # print result
            if print_cost == True:
                print('Cost after epoch %i: %f' %(epo+1, minibatch_cost))
                print('Validation cost after epoch %i: %f' %(epo+1, cost_test))
                
                print('Training accuracy after epoch %i: %f' %(epo+1, acc_train))

                print('Validation accuracy after epoch %i: %f' %(epo+1, acc_test))
        
        
        # plot cost
        plt.plot(np.arange(1,epochs+1),np.squeeze(costs), label = 'train')
        plt.plot(np.arange(1,epochs+1),np.squeeze(costs_test), label = 'validation')
        plt.ylabel('cost')
        plt.xlabel('epochs')
        plt.xticks(range(0,epochs+1,epochs//10))
        plt.legend()
        plt.show()
        
        # plot accuracy
        plt.plot(np.arange(1,epochs+1),np.squeeze(accs_train), label = 'train')
        plt.plot(np.arange(1,epochs+1),np.squeeze(accs_test), label = 'validation')
        plt.ylabel('accuracy')
        plt.xlabel('epochs')
        plt.xticks(range(0,epochs+1,epochs//10))
        plt.legend()
        plt.show()       
        
        
        return parameters

# %%
parameters = training(X_train, Y_train, X_val, Y_val)
# Out:
# Cost after epoch 1: 1.787015
# Validation cost after epoch 1: 0.354847
# Training accuracy after epoch 1: 0.859894
# Validation accuracy after epoch 1: 0.901138
# Cost after epoch 2: 0.266321
# Validation cost after epoch 2: 0.186047
# Training accuracy after epoch 2: 0.946511
# Validation accuracy after epoch 2: 0.941055
# Cost after epoch 3: 0.121867
# Validation cost after epoch 3: 0.171090
# Training accuracy after epoch 3: 0.961559
# Validation accuracy after epoch 3: 0.941262
# Cost after epoch 4: 0.079817
# Validation cost after epoch 4: 0.126067
# Training accuracy after epoch 4: 0.979852
# Validation accuracy after epoch 4: 0.971458
# Cost after epoch 5: 0.061644
# Validation cost after epoch 5: 0.126371
# Training accuracy after epoch 5: 0.980922
# Validation accuracy after epoch 5: 0.971251
# Cost after epoch 6: 0.044639
# Validation cost after epoch 6: 0.086837
# Training accuracy after epoch 6: 0.989373
# Validation accuracy after epoch 6: 0.980145
# Cost after epoch 7: 0.042658
# Validation cost after epoch 7: 0.131979
# Training accuracy after epoch 7: 0.980566
# Validation accuracy after epoch 7: 0.971665
# Cost after epoch 8: 0.085213
# Validation cost after epoch 8: 0.176594
# Training accuracy after epoch 8: 0.982420
# Validation accuracy after epoch 8: 0.964633
# Cost after epoch 9: 0.034145
# Validation cost after epoch 9: 0.134450
# Training accuracy after epoch 9: 0.993688
# Validation accuracy after epoch 9: 0.976008
# Cost after epoch 10: 0.021082
# Validation cost after epoch 10: 0.144178
# Training accuracy after epoch 10: 0.992868
# Validation accuracy after epoch 10: 0.975181
# Cost after epoch 11: 0.025470
# Validation cost after epoch 11: 0.113070
# Training accuracy after epoch 11: 0.994187
# Validation accuracy after epoch 11: 0.973733
# Cost after epoch 12: 0.019685
# Validation cost after epoch 12: 0.144282
# Training accuracy after epoch 12: 0.995257
# Validation accuracy after epoch 12: 0.979317
# Cost after epoch 13: 0.023176
# Validation cost after epoch 13: 0.149084
# Training accuracy after epoch 13: 0.994223
# Validation accuracy after epoch 13: 0.977870
# Cost after epoch 14: 0.019046
# Validation cost after epoch 14: 0.150420
# Training accuracy after epoch 14: 0.993332
# Validation accuracy after epoch 14: 0.966908
# Cost after epoch 15: 0.024002
# Validation cost after epoch 15: 0.135665
# Training accuracy after epoch 15: 0.991477
# Validation accuracy after epoch 15: 0.975181
# Cost after epoch 16: 0.022927
# Validation cost after epoch 16: 0.100129
# Training accuracy after epoch 16: 0.996149
# Validation accuracy after epoch 16: 0.981179
# Cost after epoch 17: 0.020252
# Validation cost after epoch 17: 0.093104
# Training accuracy after epoch 17: 0.991691
# Validation accuracy after epoch 17: 0.974147
# Cost after epoch 18: 0.033075
# Validation cost after epoch 18: 0.140471
# Training accuracy after epoch 18: 0.993653
# Validation accuracy after epoch 18: 0.980765
# Cost after epoch 19: 0.027191
# Validation cost after epoch 19: 0.134837
# Training accuracy after epoch 19: 0.993653
# Validation accuracy after epoch 19: 0.974974
# Cost after epoch 20: 0.037027
# Validation cost after epoch 20: 0.115318
# Training accuracy after epoch 20: 0.996363
# Validation accuracy after epoch 20: 0.978904
# Cost after epoch 21: 0.013727
# Validation cost after epoch 21: 0.170899
# Training accuracy after epoch 21: 0.993260
# Validation accuracy after epoch 21: 0.975181
# Cost after epoch 22: 0.010860
# Validation cost after epoch 22: 0.133852
# Training accuracy after epoch 22: 0.997468
# Validation accuracy after epoch 22: 0.981386
# Cost after epoch 23: 0.010868
# Validation cost after epoch 23: 0.109738
# Training accuracy after epoch 23: 0.993617
# Validation accuracy after epoch 23: 0.978490
# Cost after epoch 24: 0.017753
# Validation cost after epoch 24: 0.149368
# Training accuracy after epoch 24: 0.991513
# Validation accuracy after epoch 24: 0.968356
# Cost after epoch 25: 0.018401
# Validation cost after epoch 25: 0.110583
# Training accuracy after epoch 25: 0.994615
# Validation accuracy after epoch 25: 0.977663
# Cost after epoch 26: 0.014997
# Validation cost after epoch 26: 0.132645
# Training accuracy after epoch 26: 0.996291
# Validation accuracy after epoch 26: 0.975388
# Cost after epoch 27: 0.017334
# Validation cost after epoch 27: 0.152671
# Training accuracy after epoch 27: 0.996791
# Validation accuracy after epoch 27: 0.972906
# Cost after epoch 28: 0.013232
# Validation cost after epoch 28: 0.115845
# Training accuracy after epoch 28: 0.992048
# Validation accuracy after epoch 28: 0.979524
# Cost after epoch 29: 0.013940
# Validation cost after epoch 29: 0.097228
# Training accuracy after epoch 29: 0.990336
# Validation accuracy after epoch 29: 0.978283
# Cost after epoch 30: 0.014815
# Validation cost after epoch 30: 0.122785
# Training accuracy after epoch 30: 0.996648
# Validation accuracy after epoch 30: 0.979731
