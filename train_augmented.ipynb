# %%
# import lib
from __future__ import print_function
import numpy as np 
import math
import h5py
import matplotlib.pyplot as plt
import scipy
from PIL import Image
from scipy import ndimage
import tensorflow as tf
from tensorflow.python.framework import ops
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
# choose data
#%run 'Data Preprocessing.py'
#%run 'DA-Gaussian.py'
#%run 'DA-salt&pepper.py'
# %run 'DA-perspective.py'
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_val shape: " + str(X_val.shape))
print ("Y_val shape: " + str(Y_val.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# Loading training set...
# Done
# Loading test set...
# Done
# Splitting into val/test set...
# Done
# Normalization...
# Done
# Converting to one-hot code...
# Done
# Generating perspective images...
# Done
# Stacking perspective images...
# Done
# Finished!
# number of training examples = 57472
# number of test examples = 4832
# X_train shape: (57472, 100, 100, 3)
# Y_train shape: (57472, 60)
# X_val shape: (4841, 100, 100, 3)
# Y_val shape: (4841, 60)
# X_test shape: (4832, 100, 100, 3)
# Y_test shape: (4832, 60)

# %%
# create placeholder for x and y
def create_placeholders(n_H0, n_W0, n_C0, n_y):

    X = tf.placeholder(tf.float32, shape=[None, n_H0, n_W0, n_C0])
    Y = tf.placeholder(tf.float32, shape=[None, n_y])
    
    return X, Y

x, y = create_placeholders(100, 100, 3, 60)
print ("x = " + str(x))
print ("y = " + str(y))
# Out:
# x = Tensor("Placeholder:0", shape=(?, 100, 100, 3), dtype=float32)
# y = Tensor("Placeholder_1:0", shape=(?, 60), dtype=float32)

# %%
# initialize parameters

def initialize_parameters():
    
    tf.set_random_seed(1)
    
    w1_shape = [3,3,3,16]
    w2_shape = [3,3,16,32]
    w3_shape = [3,3,32,32]
    w4_shape = [3,3,32,64]

    
    w1 = tf.get_variable('w1', w1_shape, initializer = tf.contrib.layers.xavier_initializer(seed=0))
    w2 = tf.get_variable('w2', w2_shape, initializer = tf.contrib.layers.xavier_initializer(seed=0))
    w3 = tf.get_variable('w3', w3_shape, initializer = tf.contrib.layers.xavier_initializer(seed=0))
    w4 = tf.get_variable('w4', w4_shape, initializer = tf.contrib.layers.xavier_initializer(seed=0))
    
    parameters = {'w1': w1, 'w2': w2, 'w3': w3, 'w4': w4}
    
    return parameters

# %%
# forward_propagation

def forward_propagation(x, parameters, prob):
    # retrieve weights
    w1 = parameters['w1']
    w2 = parameters['w2']
    w3 = parameters['w3']
    w4 = parameters['w4']
    
    # conv1: k = (3,3), input = (100,100,3), output = 16, padding=0, stride =1
    x = tf.nn.conv2d(x, w1, strides = [1, 1, 1, 1], padding = 'SAME')
    # batchnormalization
    x = tf.layers.batch_normalization(x)
    # relu
    x = tf.nn.leaky_relu(x, alpha=0.5)
    # maxpool: (2,2), stride = 2, padding = 0
    x = tf.nn.max_pool(x, ksize=[1,2,2,1], strides = [1,2,2,1], padding = 'VALID')

    
    # conv2: k = (3,3), input = 16, output = 32
    x = tf.nn.conv2d(x, w2, strides = [1,1,1,1], padding = 'SAME')
    # batchnormalization
    x = tf.layers.batch_normalization(x)
    # relu
    x = tf.nn.leaky_relu(x, alpha=0.5)
    # maxpool: (2,2)
    x = tf.nn.max_pool(x, ksize=[1,2,2,1], strides = [1,2,2,1], padding = 'VALID')
    
    # conv3
    x = tf.nn.conv2d(x, w3, strides = [1,1,1,1], padding = 'SAME')
    # batchnormalization
    x = tf.layers.batch_normalization(x)
    # relu
    x = tf.nn.leaky_relu(x, alpha=0.5)
    # maxpool: (2,2)
    x = tf.nn.max_pool(x, ksize=[1,2,2,1], strides = [1,2,2,1], padding = 'VALID')
    
    # conv4
    x = tf.nn.conv2d(x, w4, strides = [1,1,1,1], padding = 'SAME')
    # batchnormalization
    x = tf.layers.batch_normalization(x)
    # relu
    x = tf.nn.leaky_relu(x, alpha=0.5)
    # maxpool: (2,2)
    x = tf.nn.max_pool(x, ksize=[1,2,2,1], strides = [1,2,2,1], padding = 'VALID')
              
    # flatten
    x = tf.contrib.layers.flatten(x)
    
    # fully-connected 
    # dense1
    x = tf.contrib.layers.fully_connected(x, 256, activation_fn = tf.nn.relu)
    # dropout
    x = tf.nn.dropout(x, keep_prob=prob)
    
    # dense2
    y = tf.contrib.layers.fully_connected(x, 60, activation_fn = None)
    
    return y

# %%
# compute cost
def compute_cost(y_pred, y):
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = y_pred, labels = y)) 
    return cost

def compute_accuracy(y_pred, x, y, size, x_, y_, prob, dropout):
    correct_prediction = tf.equal(tf.argmax(tf.nn.softmax(y_pred),1), tf.argmax(y,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    num = int(x_.shape[0]/size)
    acc_ = 0
    for i in range(num):
        acc = accuracy.eval({x:x_[i*size:(i+1)*size], y:y_[i*size:(i+1)*size], prob:dropout})
        acc_ += acc/num

    return acc_

# %%
# training
def training(xtrain, ytrain, xtest, ytest, alpha = 0.01, epochs = 30, minibatch_size = 128, print_cost = True):
    
    ops.reset_default_graph()
    tf.set_random_seed(1)
    (m, n_H0, n_W0, n_C0) = xtrain.shape
    n_y = ytrain.shape[1]
    costs = []
    costs_test = []
    accs_train = []
    accs_test = []
    minibatch_num = int(m/minibatch_size)
    
    x,y = create_placeholders(n_H0, n_W0, n_C0, n_y)
    prob = tf.placeholder_with_default(1.0, shape=())
    
    # initialize
    parameters = initialize_parameters()
    
    # forwardprop
    y_pred = forward_propagation(x, parameters, prob)
    
    # cost function
    cost = compute_cost(y_pred, y)
    
    # backprop
    optimizer = tf.train.AdamOptimizer(alpha).minimize(cost)
       
    # initialize
    init = tf.global_variables_initializer()
    init2 = tf.local_variables_initializer()
    
     
    
    # session
    with tf.Session() as sess:
        sess.run(init)
        sess.run(init2)
                    
        # training
        for epo in range(epochs):
            tf.set_random_seed(1)
            minibatch_cost = 0
            cost_test = 0
            
            # shuffle
            minibatch = np.random.choice(np.random.permutation(m), 
                                         minibatch_size * minibatch_num).reshape(minibatch_num, minibatch_size)
            minibatch_index = np.random.permutation(minibatch_num)  
                       
            for mb in range(minibatch_num):
                i = minibatch_index[mb]
                indx = minibatch[i]
                inputs = xtrain[indx]
                labels = ytrain[indx]

                # feed the inputs
                _, temp_cost = sess.run([optimizer, cost], feed_dict={x: inputs, y: labels, prob:0.5})
                
                # calculate average cost after 1 epoch
                minibatch_cost += temp_cost / minibatch_num
            
            
            # calculate cost of test set after 1 epoch
            for i in range(5):
                temp_test = sess.run(cost, feed_dict={x:xtest[i*967:(i+1)*967], y:ytest[i*967:(i+1)*967], prob:1})
                cost_test += temp_test / 5

            
            # add cost of this epoch to the lists
            costs.append(minibatch_cost)
            costs_test.append(cost_test)
            
            acc_train = compute_accuracy(y_pred, x, y, 967, xtrain, ytrain, prob, dropout=0.5) 
            accs_train.append(acc_train)
            acc_test = compute_accuracy(y_pred, x, y, 967, xtest, ytest, prob, dropout=1) 
            accs_test.append(acc_test)
            
            # print result
            if print_cost == True:
                print('Cost after epoch %i: %f' %(epo+1, minibatch_cost))
                print('Validation cost after epoch %i: %f' %(epo+1, cost_test))
                
                print('Training accuracy after epoch %i: %f' %(epo+1, acc_train))

                print('Validation accuracy after epoch %i: %f' %(epo+1, acc_test))
        
                    
        # plot cost
        plt.plot(np.arange(1,epochs+1),np.squeeze(costs), label = 'train')
        plt.plot(np.arange(1,epochs+1),np.squeeze(costs_test), label = 'validation')
        plt.ylabel('cost')
        plt.xlabel('epochs')
        plt.xticks(range(0,epochs+1,epochs//10))
        plt.legend()
        plt.show()
        
        # plot accuracy
        plt.plot(np.arange(1,epochs+1),np.squeeze(accs_train), label = 'train')
        plt.plot(np.arange(1,epochs+1),np.squeeze(accs_test), label = 'validation')
        plt.ylabel('accuracy')
        plt.xlabel('epochs')
        plt.xticks(range(0,epochs+1,epochs//10))
        plt.legend()
        plt.show()       
        
        
        return parameters

# %%
parameters = training(X_train, Y_train, X_val, Y_val, alpha=0.001, minibatch_size=256)
# Out:
# Cost after epoch 1: 1.403354
# Validation cost after epoch 1: 0.187810
# Training accuracy after epoch 1: 0.866528
# Validation accuracy after epoch 1: 0.941055
# Cost after epoch 2: 0.257984
# Validation cost after epoch 2: 0.075269
# Training accuracy after epoch 2: 0.939810
# Validation accuracy after epoch 2: 0.974560
# Cost after epoch 3: 0.158007
# Validation cost after epoch 3: 0.093157
# Training accuracy after epoch 3: 0.963998
# Validation accuracy after epoch 3: 0.975801
# Cost after epoch 4: 0.090012
# Validation cost after epoch 4: 0.088177
# Training accuracy after epoch 4: 0.973779
# Validation accuracy after epoch 4: 0.969597
# Cost after epoch 5: 0.081975
# Validation cost after epoch 5: 0.070675
# Training accuracy after epoch 5: 0.977968
# Validation accuracy after epoch 5: 0.977870
# Cost after epoch 6: 0.063059
# Validation cost after epoch 6: 0.042504
# Training accuracy after epoch 6: 0.983401
# Validation accuracy after epoch 6: 0.985729
# Cost after epoch 7: 0.041008
# Validation cost after epoch 7: 0.063848
# Training accuracy after epoch 7: 0.979493
# Validation accuracy after epoch 7: 0.984281
# Cost after epoch 8: 0.057192
# Validation cost after epoch 8: 0.050484
# Training accuracy after epoch 8: 0.980685
# Validation accuracy after epoch 8: 0.981179
# Cost after epoch 9: 0.043132
# Validation cost after epoch 9: 0.048920
# Training accuracy after epoch 9: 0.989501
# Validation accuracy after epoch 9: 0.981799
# Cost after epoch 10: 0.043236
# Validation cost after epoch 10: 0.059148
# Training accuracy after epoch 10: 0.985838
# Validation accuracy after epoch 10: 0.983040
# Cost after epoch 11: 0.037381
# Validation cost after epoch 11: 0.064922
# Training accuracy after epoch 11: 0.990114
# Validation accuracy after epoch 11: 0.984695
# Cost after epoch 12: 0.038093
# Validation cost after epoch 12: 0.114368
# Training accuracy after epoch 12: 0.985312
# Validation accuracy after epoch 12: 0.971458
# Cost after epoch 13: 0.038846
# Validation cost after epoch 13: 0.089490
# Training accuracy after epoch 13: 0.977793
# Validation accuracy after epoch 13: 0.975595
# Cost after epoch 14: 0.031671
# Validation cost after epoch 14: 0.091077
# Training accuracy after epoch 14: 0.989221
# Validation accuracy after epoch 14: 0.977663
# Cost after epoch 15: 0.026884
# Validation cost after epoch 15: 0.054954
# Training accuracy after epoch 15: 0.985627
# Validation accuracy after epoch 15: 0.986143
# Cost after epoch 16: 0.040699
# Validation cost after epoch 16: 0.057908
# Training accuracy after epoch 16: 0.990307
# Validation accuracy after epoch 16: 0.985315
# Cost after epoch 17: 0.024038
# Validation cost after epoch 17: 0.077731
# Training accuracy after epoch 17: 0.994339
# Validation accuracy after epoch 17: 0.979731
# Cost after epoch 18: 0.023241
# Validation cost after epoch 18: 0.059935
# Training accuracy after epoch 18: 0.994374
# Validation accuracy after epoch 18: 0.984488
# Cost after epoch 19: 0.026913
# Validation cost after epoch 19: 0.130256
# Training accuracy after epoch 19: 0.985329
# Validation accuracy after epoch 19: 0.972285
# Cost after epoch 20: 0.032497
# Validation cost after epoch 20: 0.067285
# Training accuracy after epoch 20: 0.984102
# Validation accuracy after epoch 20: 0.983454
# Cost after epoch 21: 0.029164
# Validation cost after epoch 21: 0.051955
# Training accuracy after epoch 21: 0.991096
# Validation accuracy after epoch 21: 0.983454
# Cost after epoch 22: 0.015505
# Validation cost after epoch 22: 0.049626
# Training accuracy after epoch 22: 0.996512
# Validation accuracy after epoch 22: 0.988831
# Cost after epoch 23: 0.029422
# Validation cost after epoch 23: 0.053882
# Training accuracy after epoch 23: 0.992376
# Validation accuracy after epoch 23: 0.990279
# Cost after epoch 24: 0.031683
# Validation cost after epoch 24: 0.040636
# Training accuracy after epoch 24: 0.995548
# Validation accuracy after epoch 24: 0.991107
# Cost after epoch 25: 0.015894
# Validation cost after epoch 25: 0.045217
# Training accuracy after epoch 25: 0.994794
# Validation accuracy after epoch 25: 0.989245
# Cost after epoch 26: 0.021447
# Validation cost after epoch 26: 0.103051
# Training accuracy after epoch 26: 0.993217
# Validation accuracy after epoch 26: 0.977870
# Cost after epoch 27: 0.017937
# Validation cost after epoch 27: 0.078352
# Training accuracy after epoch 27: 0.990938
# Validation accuracy after epoch 27: 0.978697
# Cost after epoch 28: 0.028406
# Validation cost after epoch 28: 0.045317
# Training accuracy after epoch 28: 0.994637
# Validation accuracy after epoch 28: 0.988004
# Cost after epoch 29: 0.022985
# Validation cost after epoch 29: 0.028093
# Training accuracy after epoch 29: 0.994952
# Validation accuracy after epoch 29: 0.994002
# Cost after epoch 30: 0.012388
# Validation cost after epoch 30: 0.043619
# Training accuracy after epoch 30: 0.997301
# Validation accuracy after epoch 30: 0.989245
