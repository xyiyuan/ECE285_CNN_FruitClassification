# %%
# import lib
from __future__ import print_function
import numpy as np 
import math
import h5py
import matplotlib.pyplot as plt
import scipy
from PIL import Image
from scipy import ndimage
import tensorflow as tf
from tensorflow.python.framework import ops
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
# choose data
# %run 'data preprocessing.py'
#%run 'DA-Gaussian.py'
#%run 'DA-salt&pepper.py'
#%run 'DA-perspective.py'
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_val shape: " + str(X_val.shape))
print ("Y_val shape: " + str(Y_val.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# Loading training set...
# Done
# Loading test set...
# Done
# Splitting into val/test set...
# Done
# Normalization...
# Done
# Converting to one-hot code...
# Done
# Finished!
# number of training examples = 28736
# number of test examples = 4832
# X_train shape: (28736, 100, 100, 3)
# Y_train shape: (28736, 60)
# X_val shape: (4841, 100, 100, 3)
# Y_val shape: (4841, 60)
# X_test shape: (4832, 100, 100, 3)
# Y_test shape: (4832, 60)

# %%
# create placeholder for x and y
def create_placeholders(n_H0, n_W0, n_C0, n_y):

    X = tf.placeholder(tf.float32, shape=[None, n_H0, n_W0, n_C0])
    Y = tf.placeholder(tf.float32, shape=[None, n_y])
    
    return X, Y

x, y = create_placeholders(100, 100, 3, 60)
print ("x = " + str(x))
print ("y = " + str(y))
# Out:
# x = Tensor("Placeholder:0", shape=(?, 100, 100, 3), dtype=float32)
# y = Tensor("Placeholder_1:0", shape=(?, 60), dtype=float32)

# %%
# initialize parameters

def initialize_parameters():
    
    tf.set_random_seed(1)
    
    w1_shape = [3,3,3,16]
    w2_shape = [3,3,16,32]
    w3_shape = [3,3,32,32]
    w4_shape = [3,3,32,64]

    
    w1 = tf.get_variable('w1', w1_shape, initializer = tf.contrib.layers.xavier_initializer(seed=0))
    w2 = tf.get_variable('w2', w2_shape, initializer = tf.contrib.layers.xavier_initializer(seed=0))
    w3 = tf.get_variable('w3', w3_shape, initializer = tf.contrib.layers.xavier_initializer(seed=0))
    w4 = tf.get_variable('w4', w4_shape, initializer = tf.contrib.layers.xavier_initializer(seed=0))
    
    parameters = {'w1': w1, 'w2': w2, 'w3': w3, 'w4': w4}
    
    return parameters

# %%
# forward_propagation

def forward_propagation(x, parameters, prob):
    # retrieve weights
    w1 = parameters['w1']
    w2 = parameters['w2']
    w3 = parameters['w3']
    w4 = parameters['w4']
    
    # conv1: k = (3,3), input = (100,100,3), output = 16, padding=0, stride =1
    x = tf.nn.conv2d(x, w1, strides = [1, 1, 1, 1], padding = 'SAME')
    # batchnormalization
    x = tf.layers.batch_normalization(x)
    # relu
    x = tf.nn.leaky_relu(x, alpha=0.5)
    # maxpool: (2,2), stride = 2, padding = 0
    x = tf.nn.max_pool(x, ksize=[1,2,2,1], strides = [1,2,2,1], padding = 'VALID')

    
    # conv2: k = (3,3), input = 16, output = 32
    x = tf.nn.conv2d(x, w2, strides = [1,1,1,1], padding = 'SAME')
    # batchnormalization
    x = tf.layers.batch_normalization(x)
    # relu
    x = tf.nn.leaky_relu(x, alpha=0.5)
    # maxpool: (2,2)
    x = tf.nn.max_pool(x, ksize=[1,2,2,1], strides = [1,2,2,1], padding = 'VALID')
    
    # conv3
    x = tf.nn.conv2d(x, w3, strides = [1,1,1,1], padding = 'SAME')
    # batchnormalization
    x = tf.layers.batch_normalization(x)
    # relu
    x = tf.nn.leaky_relu(x, alpha=0.5)
    # maxpool: (2,2)
    x = tf.nn.max_pool(x, ksize=[1,2,2,1], strides = [1,2,2,1], padding = 'VALID')
    
    # conv4
    x = tf.nn.conv2d(x, w4, strides = [1,1,1,1], padding = 'SAME')
    # batchnormalization
    x = tf.layers.batch_normalization(x)
    # relu
    x = tf.nn.leaky_relu(x, alpha=0.5)
    # maxpool: (2,2)
    x = tf.nn.max_pool(x, ksize=[1,2,2,1], strides = [1,2,2,1], padding = 'VALID')
              
    # flatten
    x = tf.contrib.layers.flatten(x)
    
    # fully-connected 
    # dense1
    x = tf.contrib.layers.fully_connected(x, 256, activation_fn = tf.nn.relu)
    # dropout
    x = tf.nn.dropout(x, keep_prob=prob)
    
    # dense2
    y = tf.contrib.layers.fully_connected(x, 60, activation_fn = None)
    
    return y

# %%
# compute cost
def compute_cost(y_pred, y):
    var   = tf.trainable_variables()
    lossL2 = tf.add_n([ tf.nn.l2_loss(v) for v in var ]) * 0.001
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = y_pred, labels = y)+ lossL2 )
    return cost

def compute_accuracy(y_pred, x, y, size, x_, y_, prob, dropout):
    correct_prediction = tf.equal(tf.argmax(tf.nn.softmax(y_pred),1), tf.argmax(y,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    num = int(x_.shape[0]/size)
    acc_ = 0
    for i in range(num):
        acc = accuracy.eval({x:x_[i*size:(i+1)*size], y:y_[i*size:(i+1)*size], prob:dropout})
        acc_ += acc/num

    return acc_

# %%
# training
def training(xtrain, ytrain, xtest, ytest, alpha = 0.001, epochs = 30, minibatch_size = 256, print_cost = True):
    
    ops.reset_default_graph()
    tf.set_random_seed(1)
    (m, n_H0, n_W0, n_C0) = xtrain.shape
    n_y = ytrain.shape[1]
    costs = []
    costs_test = []
    accs_train = []
    accs_test = []
    minibatch_num = int(m/minibatch_size)
    
    x,y = create_placeholders(n_H0, n_W0, n_C0, n_y)
    prob = tf.placeholder_with_default(1.0, shape=())
    
    # initialize
    parameters = initialize_parameters()
    
    # forwardprop
    y_pred = forward_propagation(x, parameters, prob)
    
    # cost function
    cost = compute_cost(y_pred, y)
    
    # backprop
    optimizer = tf.train.AdamOptimizer(alpha).minimize(cost)
       
    # initialize
    init = tf.global_variables_initializer()
    init2 = tf.local_variables_initializer()
    
     
    
    # session
    with tf.Session() as sess:
        sess.run(init)
        sess.run(init2)
                    
        # training
        for epo in range(epochs):
            tf.set_random_seed(1)
            minibatch_cost = 0
            cost_test = 0
            
            # shuffle
            minibatch = np.random.choice(np.random.permutation(m), 
                                         minibatch_size * minibatch_num).reshape(minibatch_num, minibatch_size)
            minibatch_index = np.random.permutation(minibatch_num)  
                       
            for mb in range(minibatch_num):
                i = minibatch_index[mb]
                indx = minibatch[i]
                inputs = xtrain[indx]
                labels = ytrain[indx]

                # feed the inputs
                _, temp_cost = sess.run([optimizer, cost], feed_dict={x: inputs, y: labels, prob:0.5})
                
                # calculate average cost after 1 epoch
                minibatch_cost += temp_cost / minibatch_num
            
            
            # calculate cost of test set after 1 epoch
            for i in range(5):
                temp_test = sess.run(cost, feed_dict={x:xtest[i*967:(i+1)*967], y:ytest[i*967:(i+1)*967], prob:1})
                cost_test += temp_test / 5

            
            # add cost of this epoch to the lists
            costs.append(minibatch_cost)
            costs_test.append(cost_test)
            
            acc_train = compute_accuracy(y_pred, x, y, 967, xtrain, ytrain, prob, dropout=0.5) 
            accs_train.append(acc_train)
            acc_test = compute_accuracy(y_pred, x, y, 967, xtest, ytest, prob, dropout=1) 
            accs_test.append(acc_test)
            
            # print result
            if print_cost == True:
                print('Cost after epoch %i: %f' %(epo+1, minibatch_cost))
                print('Validation cost after epoch %i: %f' %(epo+1, cost_test))
                
                print('Training accuracy after epoch %i: %f' %(epo+1, acc_train))

                print('Validation accuracy after epoch %i: %f' %(epo+1, acc_test))
        
                    
        # plot cost
        plt.plot(np.arange(1,epochs+1),np.squeeze(costs), label = 'train')
        plt.plot(np.arange(1,epochs+1),np.squeeze(costs_test), label = 'validation')
        plt.ylabel('cost')
        plt.xlabel('epochs')
        plt.xticks(range(0,epochs+1,epochs//10))
        plt.legend()
        plt.show()
        
        # plot accuracy
        plt.plot(np.arange(1,epochs+1),np.squeeze(accs_train), label = 'train')
        plt.plot(np.arange(1,epochs+1),np.squeeze(accs_test), label = 'validation')
        plt.ylabel('accuracy')
        plt.xlabel('epochs')
        plt.xticks(range(0,epochs+1,epochs//10))
        plt.legend()
        plt.show()       
        
        
        return parameters

# %%
parameters = training(X_train, Y_train, X_val, Y_val)
# Out:
# Cost after epoch 1: 2.133785
# Validation cost after epoch 1: 0.705033
# Training accuracy after epoch 1: 0.859537
# Validation accuracy after epoch 1: 0.885212
# Cost after epoch 2: 0.605430
# Validation cost after epoch 2: 0.517272
# Training accuracy after epoch 2: 0.940306
# Validation accuracy after epoch 2: 0.943744
# Cost after epoch 3: 0.457621
# Validation cost after epoch 3: 0.431063
# Training accuracy after epoch 3: 0.971722
# Validation accuracy after epoch 3: 0.962358
# Cost after epoch 4: 0.405032
# Validation cost after epoch 4: 0.405746
# Training accuracy after epoch 4: 0.975502
# Validation accuracy after epoch 4: 0.974561
# Cost after epoch 5: 0.367114
# Validation cost after epoch 5: 0.381408
# Training accuracy after epoch 5: 0.984274
# Validation accuracy after epoch 5: 0.969183
# Cost after epoch 6: 0.344999
# Validation cost after epoch 6: 0.412083
# Training accuracy after epoch 6: 0.977784
# Validation accuracy after epoch 6: 0.960703
# Cost after epoch 7: 0.329685
# Validation cost after epoch 7: 0.344445
# Training accuracy after epoch 7: 0.979959
# Validation accuracy after epoch 7: 0.972906
# Cost after epoch 8: 0.325097
# Validation cost after epoch 8: 0.352415
# Training accuracy after epoch 8: 0.979104
# Validation accuracy after epoch 8: 0.963599
# Cost after epoch 9: 0.292728
# Validation cost after epoch 9: 0.327542
# Training accuracy after epoch 9: 0.991335
# Validation accuracy after epoch 9: 0.970838
# Cost after epoch 10: 0.284455
# Validation cost after epoch 10: 0.302334
# Training accuracy after epoch 10: 0.984666
# Validation accuracy after epoch 10: 0.979111
# Cost after epoch 11: 0.273097
# Validation cost after epoch 11: 0.276495
# Training accuracy after epoch 11: 0.986913
# Validation accuracy after epoch 11: 0.986763
# Cost after epoch 12: 0.257613
# Validation cost after epoch 12: 0.284568
# Training accuracy after epoch 12: 0.991656
# Validation accuracy after epoch 12: 0.976629
# Cost after epoch 13: 0.251983
# Validation cost after epoch 13: 0.279579
# Training accuracy after epoch 13: 0.983668
# Validation accuracy after epoch 13: 0.975801
# Cost after epoch 14: 0.243693
# Validation cost after epoch 14: 0.257958
# Training accuracy after epoch 14: 0.987804
# Validation accuracy after epoch 14: 0.984281
# Cost after epoch 15: 0.240301
# Validation cost after epoch 15: 0.275914
# Training accuracy after epoch 15: 0.992690
# Validation accuracy after epoch 15: 0.976422
# Cost after epoch 16: 0.234520
# Validation cost after epoch 16: 0.291924
# Training accuracy after epoch 16: 0.987697
# Validation accuracy after epoch 16: 0.972699
# Cost after epoch 17: 0.237277
# Validation cost after epoch 17: 0.288589
# Training accuracy after epoch 17: 0.987947
# Validation accuracy after epoch 17: 0.974147
# Cost after epoch 18: 0.229687
# Validation cost after epoch 18: 0.254611
# Training accuracy after epoch 18: 0.989980
# Validation accuracy after epoch 18: 0.982627
# Cost after epoch 19: 0.223704
# Validation cost after epoch 19: 0.241810
# Training accuracy after epoch 19: 0.988518
# Validation accuracy after epoch 19: 0.984695
# Cost after epoch 20: 0.208609
# Validation cost after epoch 20: 0.241385
# Training accuracy after epoch 20: 0.993296
# Validation accuracy after epoch 20: 0.979938
# Cost after epoch 21: 0.203827
# Validation cost after epoch 21: 0.257898
# Training accuracy after epoch 21: 0.987983
# Validation accuracy after epoch 21: 0.969183
# Cost after epoch 22: 0.210523
# Validation cost after epoch 22: 0.244138
# Training accuracy after epoch 22: 0.992725
# Validation accuracy after epoch 22: 0.976836
# Cost after epoch 23: 0.200325
# Validation cost after epoch 23: 0.245397
# Training accuracy after epoch 23: 0.995721
# Validation accuracy after epoch 23: 0.978697
# Cost after epoch 24: 0.196556
# Validation cost after epoch 24: 0.258374
# Training accuracy after epoch 24: 0.990122
# Validation accuracy after epoch 24: 0.972079
# Cost after epoch 25: 0.194995
# Validation cost after epoch 25: 0.215684
# Training accuracy after epoch 25: 0.993082
# Validation accuracy after epoch 25: 0.982834
# Cost after epoch 26: 0.182962
# Validation cost after epoch 26: 0.216106
# Training accuracy after epoch 26: 0.990835
# Validation accuracy after epoch 26: 0.980558
# Cost after epoch 27: 0.184579
# Validation cost after epoch 27: 0.253597
# Training accuracy after epoch 27: 0.991549
# Validation accuracy after epoch 27: 0.971458
# Cost after epoch 28: 0.182010
# Validation cost after epoch 28: 0.218349
# Training accuracy after epoch 28: 0.994116
# Validation accuracy after epoch 28: 0.980765
# Cost after epoch 29: 0.175339
# Validation cost after epoch 29: 0.223645
# Training accuracy after epoch 29: 0.993510
# Validation accuracy after epoch 29: 0.978904
# Cost after epoch 30: 0.169382
# Validation cost after epoch 30: 0.210434
# Training accuracy after epoch 30: 0.993546
# Validation accuracy after epoch 30: 0.982834
